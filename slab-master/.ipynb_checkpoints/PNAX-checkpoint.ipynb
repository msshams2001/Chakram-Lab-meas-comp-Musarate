# %%
import sys
sys.path.insert(0,"C:\\Program Files\\slab-master\\")
sys.path.insert(1,"C:\\Users\\MeasPC\\")

# %%
from slab.instruments import PNAX
from slab import SlabFile
# Out:
# d:\anaconda3\lib\site-packages\visa.py:13: FutureWarning: The visa module provided by PyVISA is being deprecated. You can replace `import visa` by `import pyvisa as visa` to achieve the same effect.
#
# The reason for the deprecation is the possible conflict with the visa package provided by the https://github.com/visa-sdk/visa-python which can result in hard to debug situations.
#   warnings.warn(
# Warning serial library import failed.
# C:\Program Files\slab-master\slab\instruments\nwa.py:909: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if j is 0:
# Could not load Autonics TM4 Driver
# C:\Program Files\slab-master\slab\matplotlib_text_wrapper.py:42: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if alignment is 'left':
# C:\Program Files\slab-master\slab\matplotlib_text_wrapper.py:44: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif alignment is 'right':

# %%
pna=PNAX.N5242A(address="169.254.109.0")

# %%
pna.get_id()
# Out:
# 'Keysight Technologies,N5222B,MY61253732,A.15.00.15\n'

# %%
import pnax_spectroscopy_py3
# Out:
# Warning: Could not connect proxies!
# Failed to locate the nameserver
# Keysight Technologies,N5222B,MY61253732,A.15.00.15
#
# Deviced Connected
# Configuring the NWA
# NWA Configured. IFBW = 300.000000 Hz, Read_Power = -55.000000, Drive_Power = -40.000000, NumPts = 1000, Avgs = 10
# Swept Parameter: single_tone_CW
# 00008_Readout_single_tone_CW.h5
# Setting up CW parameters
# Read Now On
# Qubit Drive Now ON
# finished downloading
# D:\OneDriveGershenson-lab\Rutgers University\GERSHENSON LAB - Documents\OurData\measMW\T187\data\00008_Readout_single_tone_CW.h5
# C:\Program Files\slab-master\slab\datamanagement.py:247: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   h5py.File.__init__(self, *args, **kwargs)

# %%
import os
os.getcwd()
# Out:
# 'D:\\OneDriveGershenson-lab\\Rutgers University\\GERSHENSON LAB - Documents\\OurData\\measMW\\T187'

# %%
from slab import *
from slab.datamanagement import SlabFile
from numpy import *
import os
import time
from slab.instruments import *
from slab.instruments import InstrumentManager

im = InstrumentManager()
nwa=PNAX.N5242A(address="169.254.109.0")
#nwa =  im['PNAX2']
print(nwa.get_id())
print('Deviced Connected')

expt_path = os.getcwd() + '\data'

# initial NWA configuration values
ifbw = 1e3
read_power = -55
probe_power = -10
sweep_pts = 1000
avgs = 100
avgs_state = 1
delay = -12.41e-12

prefix = "PNAX_%s_flute cavity"

print("Configuring the NWA")

print ("NWA Configured. IFBW = %f Hz, Read_Power = %f, Drive_Power = %f, NumPts = %d, Avgs = %d " %(ifbw,read_power,probe_power,sweep_pts,avgs))

def single_tone_CW(read_freq_center,span,read_power = read_power,probe_power=probe_power,ifbw = ifbw, sweep_pts= sweep_pts,avgs=avgs,
                   avgs_state=avgs_state,is_qubitdrive= 0,qfreq= 0,measurement="S21"):

    nwa.set_timeout(10e5)
    nwa.set_ifbw(ifbw)
    nwa.set_sweep_points(sweep_pts)
    nwa.clear_traces()
    nwa.setup_measurement(measurement)
    nwa.set_electrical_delay(delay, channel=1)

    vary_param = "single_tone_CW"
    print("Swept Parameter: %s" % (vary_param))
    prefix = "Readout_%s" % vary_param
    fname = get_next_filename(expt_path, prefix, suffix='.h5')
    print(fname)
    fname = os.path.join(expt_path, fname)

    nwa.setup_take(averages=avgs)
    nwa.set_average_state(avgs_state)

    read_freq_start = read_freq_center - span/2.0
    read_freq_stop =  read_freq_center + span/2.0

    print ("Setting up CW parameters")

    nwa.set_ifbw(ifbw)

    nwa.write('SENSE:FOM:STATE 1')
    nwa.write("sense:fom:range2:coupled 1")
    nwa.write("sense:fom:range3:coupled 1")
    nwa.write("sense:fom:range4:coupled 0")
    nwa.write('SENSE:FOM:RANGE1:FREQUENCY:START %f' % read_freq_start)
    nwa.write('SENSE:FOM:RANGE1:FREQUENCY:STOP %f' % read_freq_stop)

    nwa.write('SENSE:FOM:RANGE4:FREQUENCY:START %f' % qfreq)
    nwa.write('SENSE:FOM:RANGE4:FREQUENCY:STOP %f' % qfreq)
    
    nwa.write(":SOURCE:POWER1 %f" % (read_power))
    nwa.write(":SOURCE1:POWER1:MODE ON")
    print ("Read power",read_power)
    print ("Read Now On")


    #setting the port powers and decoupling the powers
    if measurement == 'S21':
        nwa.write(":SOURCE:POWER3 %f" % (probe_power))
    if is_qubitdrive:
        nwa.write(":SOURCE1:POWER3:MODE ON")
        print ("Qubit Drive Now ON")
    else:
        nwa.write(":SOURCE1:POWER3:MODE OFF")
        print ("Qubit Drive Now Off")

    data = nwa.take_one_in_mag_phase()
    fpoints = data[0]
    mags = data[1]
    phases = data[2]
    print ("finished downloading")
    
    with SlabFile(fname) as f:
        f.append_line('mags', mags)
        f.append_line('phases', phases)
        f.append_line('freq', fpoints)
        f.append_pt('read_power', read_power)
        f.append_pt('probe_power', probe_power)

    print (fname)

def single_tone_power_sweep(read_power_list,read_freq_center,span,ifbw = ifbw, sweep_pts= sweep_pts,avgs=avgs,avgs_state=avgs_state,is_qubitdrive= 0,qfreq= 0,measurement="S21"):

    nwa.set_timeout(10E5)
    nwa.set_ifbw(ifbw)
    nwa.set_sweep_points(sweep_pts)
    nwa.clear_traces()
    nwa.setup_measurement(measurement)
    nwa.set_electrical_delay(delay, channel=1)


    vary_param = "single_tone_CW"

    prefix = "Single_tone_nearReadoutFreq_Transmission"
    fname = get_next_filename(expt_path, prefix, suffix='.h5')
    print(fname)
    fname = os.path.join(expt_path, fname)



    #setting the port powers and decoupling the powers

    for read_power in read_power_list:
        nwa.setup_take(averages=avgs)
        nwa.set_average_state(avgs_state)

        if read_power < -30:
            nwa.setup_take(averages=5)
        elif read_power < -25:
            nwa.setup_take(averages=5)
        else:
            nwa.setup_take(averages=1)



        read_freq_start = read_freq_center - span / 2.0
        read_freq_stop = read_freq_center + span / 2.0

        print("Setting up CW parameters")

        nwa.write('SENSE:FOM:STATE 1')
        nwa.write("sense:fom:range2:coupled 1")
        nwa.write("sense:fom:range3:coupled 1")
        nwa.write("sense:fom:range4:coupled 0")
        nwa.write('SENSE:FOM:RANGE1:FREQUENCY:START %f' % read_freq_start)
        nwa.write('SENSE:FOM:RANGE1:FREQUENCY:STOP %f' % read_freq_stop)

        nwa.write('SENSE:FOM:RANGE4:FREQUENCY:START %f' % qfreq)
        nwa.write('SENSE:FOM:RANGE4:FREQUENCY:STOP %f' % qfreq)

        # Turning off pulsed aspect of the measurement (just in case it was run before)
        # Turning the leveling of the ports to 'Internal'.   'open-loop' is for pulsed
        nwa.write("source1:power1:alc:mode INTERNAL")
        nwa.write("source1:power3:alc:mode INTERNAL")
        # Setting up the proper trigger mode.   Want to trigger on the point
        nwa.write("TRIG:SOUR EXT")
        nwa.write("SENS:SWE:TRIG:MODE POINT")

        # Turning off the "Reduce IF BW at Low Frequencies" because the PNA-X adjusts the BW automatically to correct for roll-off at low frequencies
        nwa.write("SENS:BWID:TRAC ON")

        # turning on the pulses
        nwa.write("SENS:PULS0 0")
        nwa.write("SENS:PULS1 0")
        nwa.write("SENS:PULS2 0")
        nwa.write("SENS:PULS3 0")
        nwa.write("SENS:PULS4 0")
        # turning off the inverting
        nwa.write("SENS:PULS1:INV 0")
        nwa.write("SENS:PULS2:INV 0")
        nwa.write("SENS:PULS3:INV 0")
        nwa.write("SENS:PULS4:INV 0")

        pnax = nwa
        # hacked to include switches
        # # turning off the pulses
        pnax.write("SENS:PULS0 0")  # automatically sync ADC to pulse gen
        pnax.write("SENS:PULS1 0")
        pnax.write("SENS:PULS2 0")
        pnax.write("SENS:PULS3 0")
        pnax.write("SENS:PULS4 0")
        # turning on the inverting
        pnax.write("SENS:PULS1:INV 1")
        pnax.write("SENS:PULS2:INV 1")
        pnax.write("SENS:PULS3:INV 1")
        pnax.write("SENS:PULS4:INV 1")

        nwa.write("SOUR:POW:COUP OFF")
        nwa.write(":SOURCE:POWER1 %f" % (read_power))
        nwa.write(":SOURCE1:POWER1:MODE ON")
        print ("Read Now On")

        nwa.write(":SOURCE1:POWER3:MODE OFF")
        print ("Qubit Drive Now Off")

        data = nwa.take_one_in_mag_phase()
        fpoints = data[0]
        mags = data[1]
        phases = data[2]
        print ("finished downloading")


        with SlabFile(fname) as f:
            f.append_line('mags', mags)
            f.append_line('phases', phases)
            f.append_line('freq', fpoints)
            f.append_pt('read_power', read_power)

def two_tone_CW(read_freq,probe_freq_center,span,ifbw = ifbw, read_power = read_power,probe_power = probe_power,sweep_pts= sweep_pts,avgs=avgs,avgs_state=avgs_state):
    vary_param = "twotone_CW"

    print("Swept Parameter: %s" % (vary_param))
    prefix = "%s_" % vary_param
    fname = get_next_filename(expt_path, prefix, suffix='.h5')
    print(fname)
    fname = os.path.join(expt_path, fname)

    rfreq =  read_freq

    nwa.set_timeout(10e5)
    nwa.set_ifbw(ifbw)
    nwa.set_sweep_points(sweep_pts)
    nwa.clear_traces()
    nwa.setup_measurement("S21")
    nwa.set_electrical_delay(delay, channel=1)


    nwa.setup_take(averages=avgs)
    nwa.set_average_state(avgs_state)

    probe_start_freq = probe_freq_center-span/2.0
    probe_stop_freq = probe_freq_center+span/2.0
#
    print ("Setting up pulsed parameters")

    nwa.set_ifbw(ifbw)

    nwa.write('SENSE:FOM:STATE 1')
    nwa.write("sense:fom:range2:coupled 0")
    nwa.write("sense:fom:range3:coupled 0")
    nwa.write("sense:fom:range4:coupled 1")
    nwa.write('SENSE:FOM:RANGE1:FREQUENCY:START %f' % probe_start_freq)
    nwa.write('SENSE:FOM:RANGE1:FREQUENCY:STOP %f' % probe_stop_freq)

    nwa.write('SENSE:FOM:RANGE2:FREQUENCY:START %f' % rfreq)
    nwa.write('SENSE:FOM:RANGE2:FREQUENCY:STOP %f' % rfreq)
    nwa.write('SENSE:FOM:RANGE3:FREQUENCY:START %f' % rfreq)
    nwa.write('SENSE:FOM:RANGE3:FREQUENCY:STOP %f' % rfreq)

    print ("set read freq")

    # setting the port powers and decoupling the powers
    nwa.write("SOUR:POW:COUP OFF")

    nwa.write(":SOURCE:POWER1 %f" % (read_power))
    nwa.write(":SOURCE1:POWER1:MODE ON")
    print ("Read Now On")

    nwa.write(":SOURCE:POWER3 %f" % (probe_power))
    nwa.write(":SOURCE1:POWER3:MODE ON")
    print ("Qubit Drive Now ON")

    data = nwa.take_one_in_mag_phase()
    fpoints = data[0]
    mags = data[1]
    phases = data[2]
    print ("finished downloading at frequency %.3f GHz" %(fpoints[0]/10**9))

    with SlabFile(fname) as f:
        f.append_line('freq', fpoints)
        f.append_line('mags', mags)
        f.append_line('phases', phases)
        f.append_pt('read_power', read_power)
        f.append_pt('probe_power', probe_power)
    return fname
def two_tone_power_sweep(probe_power_list,read_freq,probe_freq_center,span,ifbw = ifbw, read_power = read_power,sweep_pts= sweep_pts,avgs=avgs,avgs_state=avgs_state):
    #vary_param = "qubit_twotone_CW"

   # print("Swept Parameter: %s" % (vary_param))
    prefix = "twotoneVsPowerTransmission"
    fname = get_next_filename(expt_path, prefix, suffix='.h5')
    print(fname)
    fname = os.path.join(expt_path, fname)

    rfreq =  read_freq

    nwa.set_timeout(10e5)
    nwa.set_ifbw(ifbw)
    nwa.set_sweep_points(sweep_pts)
    nwa.clear_traces()
    nwa.setup_measurement("S21")
    nwa.set_electrical_delay(delay, channel=1)
    nwa.setup_take(averages=avgs)
    nwa.set_average_state(avgs_state)

    for probe_power in probe_power_list:
        nwa.setup_take(averages=avgs)

        probe_start_freq = probe_freq_center-span/2.0
        probe_stop_freq = probe_freq_center+span/2.0
    #
        print ("Setting up pulsed parameters")

        nwa.set_ifbw(ifbw)

        nwa.write('SENSE:FOM:STATE 1')
        nwa.write("sense:fom:range2:coupled 0")
        nwa.write("sense:fom:range3:coupled 0")
        nwa.write("sense:fom:range4:coupled 1")
        nwa.write('SENSE:FOM:RANGE1:FREQUENCY:START %f' % probe_start_freq)
        nwa.write('SENSE:FOM:RANGE1:FREQUENCY:STOP %f' % probe_stop_freq)

        nwa.write('SENSE:FOM:RANGE2:FREQUENCY:START %f' % rfreq)
        nwa.write('SENSE:FOM:RANGE2:FREQUENCY:STOP %f' % rfreq)
        nwa.write('SENSE:FOM:RANGE3:FREQUENCY:START %f' % rfreq)
        nwa.write('SENSE:FOM:RANGE3:FREQUENCY:STOP %f' % rfreq)

        print ("set read freq")

        # Turning off pulsed aspect of the measurement (just in case it was run before)
        # Turning the leveling of the ports to 'Internal'.   'open-loop' is for pulsed
        nwa.write("source1:power1:alc:mode INTERNAL")
        nwa.write("source1:power3:alc:mode INTERNAL")
        # Setting up the proper trigger mode.   Want to trigger on the point
        nwa.write("TRIG:SOUR EXT")
        nwa.write("SENS:SWE:TRIG:MODE POINT")

        # Turning off the "Reduce IF BW at Low Frequencies" because the PNA-X adjusts the BW automatically to correct for roll-off at low frequencies
        nwa.write("SENS:BWID:TRAC ON")

        # setting the port powers and decoupling the powers
        nwa.write("SOUR:POW:COUP OFF")

        nwa.write(":SOURCE:POWER1 %f" % (read_power))
        nwa.write(":SOURCE1:POWER1:MODE ON")
        print ("Read Now On")

        nwa.write(":SOURCE:POWER3 %f" % (probe_power))
        nwa.write(":SOURCE1:POWER3:MODE ON")
        print ("Qubit Drive Now ON")

        data = nwa.take_one_in_mag_phase()
        fpoints = data[0]
        mags = data[1]
        phases = data[2]

        print ("finished downloading at frequency %.3f GHz" %(fpoints[0]/10**9))

        with SlabFile(fname) as f:
            f.append_line('freq', fpoints)
            f.append_line('mags', mags)
            f.append_line('phases', phases)
            f.append_pt('read_power', read_power)
            f.append_pt('probe_power', probe_power)



# read_power_list = arange(-21,5,1)
# single_tone_power_sweep(read_power_list,read_freq_center = read_freq,span = 100e6)
#
# read_freq  =   7.767947746052817e9
# single_tone_power_sweep(read_power_list,read_freq_center = read_freq,span = 5e6)
#
#
# single_tone_CW(read_freq, 6.17e6, measurement="S21",is_qubitdrive=False,qfreq = 3.810241016669044e9)



# two_tone_CW(read_freq,probe_freq_center=6.6e9, span =  2.4e9)
# two_tone_power_sweep(probe_power_list = arange(-55,0,1),read_freq=read_freq,probe_freq_center=6.0e9,span=2.2e9)
# Out:
# Warning: Could not connect proxies!
# Failed to locate the nameserver
# Keysight Technologies,N5222B,MY61253732,A.15.00.15
#
# Deviced Connected
# Configuring the NWA
# NWA Configured. IFBW = 1000.000000 Hz, Read_Power = -55.000000, Drive_Power = -10.000000, NumPts = 1000, Avgs = 100

# %%
ts = []
for i in range(50):
    ts.append(time.time())
    print("elapsed time {:0.1f}".format(ts[i]-ts[0]))
#     read_freq  =  7.24e9
    single_tone_CW(read_freq, 1e6,read_power=-40, avgs=1,ifbw = 300,measurement="S21",is_qubitdrive=False,qfreq = 4.865e9)
    single_tone_CW(read_freq, 1e6,read_power=-40, avgs=1,ifbw = 300,measurement="S21",is_qubitdrive=True,qfreq = 4.865e9)
#     two_tone_CW(read_freq,probe_freq_center=4.265e9, span =20e6,read_power=-40,probe_power=-25,sweep_pts=1000)
#     time.sleep(20)
# Out:
# elapsed time 0.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-373fa702c11c> in <module>
#       4     print("elapsed time {:0.1f}".format(ts[i]-ts[0]))
#       5 #     read_freq  =  7.24e9
# ----> 6     single_tone_CW(read_freq, 1e6,read_power=-40, avgs=1,ifbw = 300,measurement="S21",is_qubitdrive=False,qfreq = 4.865e9)
#       7     single_tone_CW(read_freq, 1e6,read_power=-40, avgs=1,ifbw = 300,measurement="S21",is_qubitdrive=True,qfreq = 4.865e9)
#       8 #     two_tone_CW(read_freq,probe_freq_center=4.265e9, span =20e6,read_power=-40,probe_power=-25,sweep_pts=1000)
#
# NameError: name 'read_freq' is not defined

# %%
mags_all=[]
for i in range(27+1,42,2):
    filename = "D:\\OneDriveGershenson-lab\\Rutgers University\\GERSHENSON LAB - Documents\\OurData\\measMW\\T178\\data\\000"+str(i)+"_Readout_single_tone_CW.h5"

    with h5py.File(filename, 'r') as f:
        mags = f['mags']
        freqs = f['freq']
        phases = f['phases']
        read_power=f['read_power']
        mags=np.array(mags[:]).flatten()
        phases=np.array(phases[:]).flatten()
        freqs=np.array(freqs[:]).flatten()
#         for key in f.keys():
#             print(key)
            
    mags_all.append(mags)
ts=np.array(ts)
plt.pcolormesh(freqs,(ts-ts[0])/3600,np.array(mags_all))

plt.show()
# plt.plot(freqs,np.mean(mags_all,axis=0))
# plt.plot(freqs,mags_all[15])
# plt.plot(freqs,mags_all[1])
# Out:
# <ipython-input-29-c99fa9d3c00b>:18: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(freqs,(ts-ts[0])/3600,np.array(mags_all))

# %%
filename = "D:\\OneDriveGershenson-lab\\Rutgers University\\GERSHENSON LAB - Documents\\OurData\\measMW\\T172\\data\\scan_53_89.h5"
with SlabFile(filename) as f:
    f.append_line('times', ts)
# Out:
# C:\Program Files\slab-master\slab\datamanagement.py:247: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   h5py.File.__init__(self, *args, **kwargs)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-528d0187d4d2> in <module>
#       1 filename = "D:\\OneDriveGershenson-lab\\Rutgers University\\GERSHENSON LAB - Documents\\OurData\\measMW\\T172\\data\\scan_53_89.h5"
#       2 with SlabFile(filename) as f:
# ----> 3     f.append_line('times', ts)
#
# NameError: name 'ts' is not defined

# %%
import h5py


# h5 = h5py.File(filename,'r')

# print(h5)

# h5.close()

# %%
read_freq=7.238e9
# read_freq=7.192e9

# probe_power=-25
single_tone_CW(read_freq, 200e6,read_power=-40, avgs=10,ifbw = 1000,probe_power=-35,measurement="S21",is_qubitdrive=False,qfreq = 4.44e9)
# Out:
# Swept Parameter: single_tone_CW
# 00009_Readout_single_tone_CW.h5
# Setting up CW parameters
# Read power -40
# Read Now On
# Qubit Drive Now Off
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-249fc21d9a0f> in <module>
#       3
#       4 # probe_power=-25
# ----> 5 single_tone_CW(read_freq, 200e6,read_power=-40, avgs=10,ifbw = 1000,probe_power=-35,measurement="S21",is_qubitdrive=False,qfreq = 4.44e9)
#
# <ipython-input-7-6b4b8ca79af2> in single_tone_CW(read_freq_center, span, read_power, probe_power, ifbw, sweep_pts, avgs, avgs_state, is_qubitdrive, qfreq, measurement)
#      83         print ("Qubit Drive Now Off")
#      84
# ---> 85     data = nwa.take_one_in_mag_phase()
#      86     fpoints = data[0]
#      87     mags = data[1]
#
# C:\Program Files\slab-master\slab\instruments\PNAX.py in take_one_in_mag_phase(self, sweep_points, data_format)
#     631         _format = self.get_format()
#     632         self.setup_take()
# --> 633         fpts, xs, ys = self.take(sweep_points=sweep_points, data_format=data_format)
#     634         mags, phases = polar2mag(xs, ys)
#     635         self.set_trigger_source(_trig_source)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
read_power_list = arange(-50,0,5)
single_tone_power_sweep(read_power_list,read_freq_center=read_freq, span=5e6, avgs=10,ifbw = 1000,measurement="S21",is_qubitdrive=False,qfreq = 4.44e9)
# Out:
# 00010_Single_tone_nearReadoutFreq_Transmission.h5
# Setting up CW parameters
# Read Now On
# Qubit Drive Now Off
# finished downloading
# Setting up CW parameters
# Read Now On
# Qubit Drive Now Off
# finished downloading
# Setting up CW parameters
# Read Now On
# Qubit Drive Now Off
# finished downloading
# Setting up CW parameters
# Read Now On
# Qubit Drive Now Off
# finished downloading
# Setting up CW parameters
# Read Now On
# Qubit Drive Now Off
# finished downloading
# Setting up CW parameters
# Read Now On
# Qubit Drive Now Off
# finished downloading
# Setting up CW parameters
# Read Now On
# Qubit Drive Now Off
# finished downloading
# Setting up CW parameters
# Read Now On
# Qubit Drive Now Off
# finished downloading
# Setting up CW parameters
# Read Now On
# Qubit Drive Now Off
# finished downloading
# Setting up CW parameters
# Read Now On
# Qubit Drive Now Off
# finished downloading

# %%
filename = "D:\\OneDriveGershenson-lab\\Rutgers University\\GERSHENSON LAB - Documents\\OurData\\measMW\\T187\\data\\00010_Single_tone_nearReadoutFreq_Transmission.h5"

with h5py.File(filename, 'r') as f:
    mags = f['mags']
    freqs = f['freq']
    phases = f['phases']
    read_power=f['read_power']
    read_power=np.array(read_power[:]).flatten()
    mags=np.array(mags[:])
    phases=np.array(phases[:]).flatten()
    freqs=np.array(freqs[0,:]).flatten()
    for key in f.keys():
        print(key)
        
plt.pcolormesh(freqs,read_power,mags)
plt.show()
for i in range(len(read_power)):
    plt.plot(freqs,mags[i])
# Out:
# freq
# mags
# phases
# read_power
# <ipython-input-62-9575aee0aa31>:15: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(freqs,read_power,mags)

# %%
    plt.plot(freqs,mags[0])
    plt.plot(freqs,mags[-1])
    print(freqs[np.argmax(mags[0])])
# Out:
# 7237777276.577578

# %%
filename = "D:\\OneDriveGershenson-lab\\Rutgers University\\GERSHENSON LAB - Documents\\OurData\\measMW\\T187\\data\\00004_Readout_single_tone_CW.h5"

with h5py.File(filename, 'r') as f:
    mags = f['mags']
    freqs = f['freq']
    phases = f['phases']
    read_power=f['read_power']
    mags=np.array(mags[:]).flatten()
    phases=np.array(phases[:]).flatten()
    freqs=np.array(freqs[:]).flatten()
    for key in f.keys():
        print(key)
f,ax=plt.subplots()
print(read_power)
ax.plot(freqs,mags,'-')
print(freqs[np.argmax(mags)])
# Out:
# freq
# mags
# phases
# probe_power
# read_power
# <Closed HDF5 dataset>
# 7239501501.501501

# %%
read_freq=7239501501
# read_freq=7.2385e9
filename=two_tone_CW(read_freq,probe_freq_center=3.91e9, span =100e6,read_power=-40,probe_power=-10,sweep_pts=1000,avgs=5,ifbw=300)
print(filename)
# filename = "D:\\OneDriveGershenson-lab\\Rutgers University\\GERSHENSON LAB - Documents\\OurData\\measMW\\PNAX\\data\\00069_twotone_CW_.h5"
with h5py.File(filename, 'r') as f:
    mags = f['mags']
    freqs = f['freq']
    phases = f['phases']
    mags=np.array(mags[:]).flatten()
    phases=np.array(phases[:]).flatten()
    freqs=np.array(freqs[:]).flatten()
    for key in f.keys():
        print(key)
fig = plt.figure(figsize = (10,5))
ax = fig.add_subplot(111)

ax.plot(freqs,mags,'-')
# Out:
# Swept Parameter: twotone_CW
# 00031_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.860 GHz
# D:\OneDriveGershenson-lab\Rutgers University\GERSHENSON LAB - Documents\OurData\measMW\T187\data\00031_twotone_CW_.h5
# freq
# mags
# phases
# probe_power
# read_power
# C:\Program Files\slab-master\slab\datamanagement.py:247: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   h5py.File.__init__(self, *args, **kwargs)

# %%
plt.plot(freqs,mags,'-')

# %%
from qcodes.instrument.base import Instrument

Instrument.close_all()

# %%
from qcodes.instrument_drivers.Lakeshore.Model_372 import Model_372
LS370 = Model_372(name = 'LS370inputCh', address = 'GPIB::12::INSTR', terminator='\n')
T6 = LS370.ch06.temperature
T6.get()
# Out:
# Connected to: LSCI 370 (serial:370557, firmware:04102008) in 0.07s
# 0.137099

# %%
LS370.analog_heater.outmode
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-d9279207a58c> in <module>
# ----> 1 LS370.analog_heater.outmode
#
# d:\anaconda3\lib\site-packages\qcodes\utils\helpers.py in __getattr__(self, key)
#     404                 pass
#     405
# --> 406         raise AttributeError(
#     407             "'{}' object and its delegates have no attribute '{}'".format(
#     408                 self.__class__.__name__, key))
#
# AttributeError: 'Output_372' object and its delegates have no attribute 'outmode'

# %%
LS370.analog_heater.polarity.set('unipolar')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\anaconda3\lib\site-packages\qcodes\instrument\parameter.py in _from_raw_value_to_value(self, raw_value)
#     563                 try:
# --> 564                     value = self.inverse_val_mapping[int(value)]
#     565                 except (ValueError, KeyError):
#
# ValueError: invalid literal for int() with base 10: 'LSCI'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-120-90df097aaeb3> in <module>
# ----> 1 LS370.analog_heater.polarity.set('unipolar')
#
# d:\anaconda3\lib\site-packages\qcodes\instrument\parameter.py in set_wrapper(value, **kwargs)
#     643             except Exception as e:
#     644                 e.args = e.args + (f'setting {self} to {value}',)
# --> 645                 raise e
#     646
#     647         return set_wrapper
#
# d:\anaconda3\lib\site-packages\qcodes\instrument\parameter.py in set_wrapper(value, **kwargs)
#     627                     t0 = time.perf_counter()
#     628
# --> 629                     set_function(raw_val_step, **kwargs)
#     630
#     631                     # Update last set time (used for calculating delays)
#
# d:\anaconda3\lib\site-packages\qcodes\instrument\group_parameter.py in set_raw(self, value)
#      76             raise RuntimeError("Trying to set Group value but no "
#      77                                "group defined")
# ---> 78         self.group._set_one_parameter_from_raw(self, value)
#      79
#      80
#
# d:\anaconda3\lib\site-packages\qcodes\instrument\group_parameter.py in _set_one_parameter_from_raw(self, set_parameter, raw_value)
#     249         """
#     250         # TODO replace get latest with call to cache.invalid once that lands
# --> 251         if any((p.get_latest() is None) for p in self.parameters.values()):
#     252             self.update()
#     253         calling_dict = {name: p.cache.raw_value
#
# d:\anaconda3\lib\site-packages\qcodes\instrument\group_parameter.py in <genexpr>(.0)
#     249         """
#     250         # TODO replace get latest with call to cache.invalid once that lands
# --> 251         if any((p.get_latest() is None) for p in self.parameters.values()):
#     252             self.update()
#     253         calling_dict = {name: p.cache.raw_value
#
# d:\anaconda3\lib\site-packages\qcodes\instrument\parameter.py in __call__(self)
#    2269         It is recommended to use ``parameter.cache()`` instead.
#    2270         """
# -> 2271         return self.cache()
#    2272
#    2273
#
# d:\anaconda3\lib\site-packages\qcodes\instrument\parameter.py in __call__(self)
#    2203         cache is not valid
#    2204         """
# -> 2205         return self.get(get_if_invalid=True)
#    2206
#    2207
#
# d:\anaconda3\lib\site-packages\qcodes\instrument\parameter.py in get(self, get_if_invalid)
#    2167             if get_if_invalid:
#    2168                 if gettable:
# -> 2169                     return self._parameter.get()
#    2170                 else:
#    2171                     error_msg = self._construct_error_msg()
#
# d:\anaconda3\lib\site-packages\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     590             except Exception as e:
#     591                 e.args = e.args + (f'getting {self}',)
# --> 592                 raise e
#     593
#     594         return get_wrapper
#
# d:\anaconda3\lib\site-packages\qcodes\instrument\parameter.py in get_wrapper(*args, **kwargs)
#     577             try:
#     578                 # There might be cases where a .get also has args/kwargs
# --> 579                 raw_value = get_function(*args, **kwargs)
#     580
#     581                 value = self._from_raw_value_to_value(raw_value)
#
# d:\anaconda3\lib\site-packages\qcodes\instrument\group_parameter.py in get_raw(self)
#      69             raise RuntimeError("Trying to get Group value but no "
#      70                                "group defined")
# ---> 71         self.group.update()
#      72         return self.cache.raw_value
#      73
#
# d:\anaconda3\lib\site-packages\qcodes\instrument\group_parameter.py in update(self)
#     288         ret = self.get_parser(self.instrument.ask(self._get_cmd))
#     289         for name, p in list(self.parameters.items()):
# --> 290             p.cache._set_from_raw_value(ret[name])
#     291
#     292     @property
#
# d:\anaconda3\lib\site-packages\qcodes\instrument\parameter.py in _set_from_raw_value(self, raw_value)
#    2098
#    2099     def _set_from_raw_value(self, raw_value: ParamRawDataType) -> None:
# -> 2100         value = self._parameter._from_raw_value_to_value(raw_value)
#    2101         if self._parameter._validate_on_get:
#    2102             self._parameter.validate(value)
#
# d:\anaconda3\lib\site-packages\qcodes\instrument\parameter.py in _from_raw_value_to_value(self, raw_value)
#     564                     value = self.inverse_val_mapping[int(value)]
#     565                 except (ValueError, KeyError):
# --> 566                     raise KeyError(f"'{value}' not in val_mapping")
#     567
#     568         return value
#
# KeyError: ("'LSCI' not in val_mapping", 'getting LS370inputCh_analog_heater_mode', 'setting LS370inputCh_analog_heater_polarity to unipolar')

# %%
ts = []
temps=[]
filenames=[]
for i in range(100):
    ts.append(time.time())
#     temps.append(T6.get())
    print("elapsed time {:0.1f}".format(ts[i]-ts[0]))
    filename=two_tone_CW(read_freq,probe_freq_center=3.88e9, span =100e6,read_power=-45,probe_power=-12,sweep_pts=1000,avgs=5,ifbw=300)
    filenames.append(filename)
    time.sleep(1)
# Out:
# elapsed time 0.0
# Swept Parameter: twotone_CW
# 00714_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 17.0
# Swept Parameter: twotone_CW
# 00715_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 33.9
# Swept Parameter: twotone_CW
# 00716_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 51.0
# Swept Parameter: twotone_CW
# 00717_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 68.0
# Swept Parameter: twotone_CW
# 00718_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 85.0
# Swept Parameter: twotone_CW
# 00719_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 102.0
# Swept Parameter: twotone_CW
# 00720_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 119.1
# Swept Parameter: twotone_CW
# 00721_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 136.1
# Swept Parameter: twotone_CW
# 00722_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 153.1
# Swept Parameter: twotone_CW
# 00723_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 170.2
# Swept Parameter: twotone_CW
# 00724_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 187.2
# Swept Parameter: twotone_CW
# 00725_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 204.3
# Swept Parameter: twotone_CW
# 00726_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 221.4
# Swept Parameter: twotone_CW
# 00727_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 238.4
# Swept Parameter: twotone_CW
# 00728_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 255.5
# Swept Parameter: twotone_CW
# 00729_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 272.6
# Swept Parameter: twotone_CW
# 00730_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 289.6
# Swept Parameter: twotone_CW
# 00731_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 306.7
# Swept Parameter: twotone_CW
# 00732_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 323.7
# Swept Parameter: twotone_CW
# 00733_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 340.8
# Swept Parameter: twotone_CW
# 00734_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 3.830 GHz
# elapsed time 357.7
# Swept Parameter: twotone_CW
# 00735_twotone_CW_.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-667c9d1c6269> in <module>
#       6 #     temps.append(T6.get())
#       7     print("elapsed time {:0.1f}".format(ts[i]-ts[0]))
# ----> 8     filename=two_tone_CW(read_freq,probe_freq_center=3.88e9, span =100e6,read_power=-45,probe_power=-12,sweep_pts=1000,avgs=5,ifbw=300)
#       9     filenames.append(filename)
#      10     time.sleep(1)
#
# <ipython-input-7-6b4b8ca79af2> in two_tone_CW(read_freq, probe_freq_center, span, ifbw, read_power, probe_power, sweep_pts, avgs, avgs_state)
#     259     print ("Qubit Drive Now ON")
#     260
# --> 261     data = nwa.take_one_in_mag_phase()
#     262     fpoints = data[0]
#     263     mags = data[1]
#
# C:\Program Files\slab-master\slab\instruments\PNAX.py in take_one_in_mag_phase(self, sweep_points, data_format)
#     631         _format = self.get_format()
#     632         self.setup_take()
# --> 633         fpts, xs, ys = self.take(sweep_points=sweep_points, data_format=data_format)
#     634         mags, phases = polar2mag(xs, ys)
#     635         self.set_trigger_source(_trig_source)
#
# C:\Program Files\slab-master\slab\instruments\PNAX.py in take(self, sweep_points, data_format)
#     613         # this is the command that triggers the averaging. Execute right before read data.
#     614         self.set_sweep_mode('gro')
# --> 615         data = self.read_data(sweep_points=sweep_points, data_format=data_format)
#     616         return data
#     617
#
# C:\Program Files\slab-master\slab\instruments\PNAX.py in read_data(self, sweep_points, channel, timeout, data_format)
#     571         if timeout is None:
#     572             timeout = self.timeout
# --> 573         self.get_operation_completion()
#     574         self.read(timeout=0.1)
#     575         self.write("CALC%d:DATA? FDATA" % channel)
#
# C:\Program Files\slab-master\slab\instruments\PNAX.py in get_operation_completion(self)
#     225
#     226     def get_operation_completion(self):
# --> 227         data = self.query("*OPC?")
#     228         if data is None:
#     229             return False
#
# C:\Program Files\slab-master\slab\instruments\instrumenttypes.py in query(self, cmd, timeout)
#      66         self.write(cmd)
#      67         time.sleep(self.query_sleep)
# ---> 68         return self.read(timeout)
#      69
#      70     def queryb(self, cmd, timeout=None):
#
# C:\Program Files\slab-master\slab\instruments\instrumenttypes.py in read(self, timeout)
#     194     def read(self, timeout=None):
#     195         if timeout == None: timeout = self.timeout
# --> 196         ready = select.select([self.socket], [], [], timeout)
#     197         if (ready[0] and self.enabled):
#     198             return self.socket.recv(self.recv_length).decode()
#
# KeyboardInterrupt:

# %%
#46 to 107 25 mK

mags_all=[]
t_set=range(46,107,1)
# for i in range(2,8,1):
# for i in range(8,24,1):
for i in range(46,107,1):

    filename = "D:\\OneDriveGershenson-lab\\Rutgers University\\GERSHENSON LAB - Documents\\OurData\\measMW\\T187\\data\\00"+f"{i:03}"+"_twotone_CW_.h5"

    with h5py.File(filename, 'r') as f:
        mags = f['mags']
        freqs = f['freq']
        phases = f['phases']
        read_power=f['read_power']
        mags=np.array(mags[:]).flatten()
        phases=np.array(phases[:]).flatten()
        freqs=np.array(freqs[:]).flatten()
#         for key in f.keys():
#             print(key)
            
    mags_all.append(mags)
# ts=np.array(ts)
plt.pcolormesh(freqs,t_set,np.array(mags_all))
plt.show()
# Out:
# <ipython-input-44-131a8fbf5487>:24: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(freqs,t_set,np.array(mags_all))

# %%
plt.plot(freqs,np.mean(np.array(mags_all),axis=0))

# %%
mags_all=[]
# for i in range(179,184,1):
# for i in range(184,191,1):
# for i in range(2,8,1):
for i in range(714,735,1):

    filename = "D:\\OneDriveGershenson-lab\\Rutgers University\\GERSHENSON LAB - Documents\\OurData\\measMW\\T187\\data\\00"+f"{i:03}"+"_twotone_CW_.h5"

    with h5py.File(filename, 'r') as f:
        mags = f['mags']
        freqs = f['freq']
        phases = f['phases']
        read_power=f['read_power']
        mags=np.array(mags[:]).flatten()
        phases=np.array(phases[:]).flatten()
        freqs=np.array(freqs[:]).flatten()
#         for key in f.keys():
#             print(key)
            
    mags_all.append(mags)
ts=np.array(ts)
print(ts)
plt.pcolormesh(freqs,ts,np.array(mags_all))
plt.show()
# Out:
# [1.66285171e+09 1.66285173e+09 1.66285175e+09 1.66285176e+09
#  1.66285178e+09 1.66285180e+09 1.66285181e+09 1.66285183e+09
#  1.66285185e+09 1.66285186e+09 1.66285188e+09 1.66285190e+09
#  1.66285192e+09 1.66285193e+09 1.66285195e+09 1.66285197e+09
#  1.66285198e+09 1.66285200e+09 1.66285202e+09 1.66285204e+09
#  1.66285205e+09 1.66285207e+09]
# <ipython-input-80-dbdb39442879>:23: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(freqs,ts,np.array(mags_all))

# %%
plt.plot(freqs,np.mean(np.array(mags_all),axis=0))

# %%
mags_all=[]
# for i in range(179,184,1):
# for i in range(184,191,1):
# for i in range(2,8,1):
for i in range(143,643,1):

    filename = "D:\\OneDriveGershenson-lab\\Rutgers University\\GERSHENSON LAB - Documents\\OurData\\measMW\\T187\\data\\00"+f"{i:03}"+"_twotone_CW_.h5"

    with h5py.File(filename, 'r') as f:
        mags = f['mags']
        freqs = f['freq']
        phases = f['phases']
        read_power=f['read_power']
        mags=np.array(mags[:]).flatten()
        phases=np.array(phases[:]).flatten()
        freqs=np.array(freqs[:]).flatten()
#         for key in f.keys():
#             print(key)
            
    mags_all.append(mags)
ts=np.array(ts)
print(ts)
plt.pcolormesh(freqs,ts,np.array(mags_all))
plt.show()
# Out:
# [1.66282962e+09 1.66282964e+09 1.66282965e+09 1.66282967e+09
#  1.66282969e+09 1.66282970e+09 1.66282972e+09 1.66282974e+09
#  1.66282976e+09 1.66282977e+09 1.66282979e+09 1.66282981e+09
#  1.66282982e+09 1.66282984e+09 1.66282986e+09 1.66282987e+09
#  1.66282989e+09 1.66282991e+09 1.66282993e+09 1.66282994e+09
#  1.66282996e+09 1.66282998e+09 1.66282999e+09 1.66283001e+09
#  1.66283003e+09 1.66283005e+09 1.66283006e+09 1.66283008e+09
#  1.66283010e+09 1.66283011e+09 1.66283013e+09 1.66283015e+09
#  1.66283016e+09 1.66283018e+09 1.66283020e+09 1.66283022e+09
#  1.66283023e+09 1.66283025e+09 1.66283027e+09 1.66283028e+09
#  1.66283030e+09 1.66283032e+09 1.66283033e+09 1.66283035e+09
#  1.66283037e+09 1.66283039e+09 1.66283040e+09 1.66283042e+09
#  1.66283044e+09 1.66283045e+09 1.66283047e+09 1.66283049e+09
#  1.66283051e+09 1.66283052e+09 1.66283054e+09 1.66283056e+09
#  1.66283057e+09 1.66283059e+09 1.66283061e+09 1.66283062e+09
#  1.66283064e+09 1.66283066e+09 1.66283068e+09 1.66283069e+09
#  1.66283071e+09 1.66283073e+09 1.66283074e+09 1.66283076e+09
#  1.66283078e+09 1.66283079e+09 1.66283081e+09 1.66283083e+09
#  1.66283085e+09 1.66283086e+09 1.66283088e+09 1.66283090e+09
#  1.66283091e+09 1.66283093e+09 1.66283095e+09 1.66283096e+09
#  1.66283098e+09 1.66283100e+09 1.66283102e+09 1.66283103e+09
#  1.66283105e+09 1.66283107e+09 1.66283108e+09 1.66283110e+09
#  1.66283112e+09 1.66283114e+09 1.66283115e+09 1.66283117e+09
#  1.66283119e+09 1.66283120e+09 1.66283122e+09 1.66283124e+09
#  1.66283125e+09 1.66283127e+09 1.66283129e+09 1.66283131e+09
#  1.66283132e+09 1.66283134e+09 1.66283136e+09 1.66283137e+09
#  1.66283139e+09 1.66283141e+09 1.66283142e+09 1.66283144e+09
#  1.66283146e+09 1.66283148e+09 1.66283149e+09 1.66283151e+09
#  1.66283153e+09 1.66283154e+09 1.66283156e+09 1.66283158e+09
#  1.66283159e+09 1.66283161e+09 1.66283163e+09 1.66283165e+09
#  1.66283166e+09 1.66283168e+09 1.66283170e+09 1.66283171e+09
#  1.66283173e+09 1.66283175e+09 1.66283177e+09 1.66283178e+09
#  1.66283180e+09 1.66283182e+09 1.66283183e+09 1.66283185e+09
#  1.66283187e+09 1.66283188e+09 1.66283190e+09 1.66283192e+09
#  1.66283194e+09 1.66283195e+09 1.66283197e+09 1.66283199e+09
#  1.66283200e+09 1.66283202e+09 1.66283204e+09 1.66283205e+09
#  1.66283207e+09 1.66283209e+09 1.66283211e+09 1.66283212e+09
#  1.66283214e+09 1.66283216e+09 1.66283217e+09 1.66283219e+09
#  1.66283221e+09 1.66283222e+09 1.66283224e+09 1.66283226e+09
#  1.66283228e+09 1.66283229e+09 1.66283231e+09 1.66283233e+09
#  1.66283234e+09 1.66283236e+09 1.66283238e+09 1.66283239e+09
#  1.66283241e+09 1.66283243e+09 1.66283245e+09 1.66283246e+09
#  1.66283248e+09 1.66283250e+09 1.66283251e+09 1.66283253e+09
#  1.66283255e+09 1.66283257e+09 1.66283258e+09 1.66283260e+09
#  1.66283262e+09 1.66283263e+09 1.66283265e+09 1.66283267e+09
#  1.66283268e+09 1.66283270e+09 1.66283272e+09 1.66283274e+09
#  1.66283275e+09 1.66283277e+09 1.66283279e+09 1.66283280e+09
#  1.66283282e+09 1.66283284e+09 1.66283285e+09 1.66283287e+09
#  1.66283289e+09 1.66283291e+09 1.66283292e+09 1.66283294e+09
#  1.66283296e+09 1.66283297e+09 1.66283299e+09 1.66283301e+09
#  1.66283302e+09 1.66283304e+09 1.66283306e+09 1.66283308e+09
#  1.66283309e+09 1.66283311e+09 1.66283313e+09 1.66283314e+09
#  1.66283316e+09 1.66283318e+09 1.66283320e+09 1.66283321e+09
#  1.66283323e+09 1.66283325e+09 1.66283326e+09 1.66283328e+09
#  1.66283330e+09 1.66283331e+09 1.66283333e+09 1.66283335e+09
#  1.66283337e+09 1.66283338e+09 1.66283340e+09 1.66283342e+09
#  1.66283343e+09 1.66283345e+09 1.66283347e+09 1.66283348e+09
#  1.66283350e+09 1.66283352e+09 1.66283354e+09 1.66283355e+09
#  1.66283357e+09 1.66283359e+09 1.66283360e+09 1.66283362e+09
#  1.66283364e+09 1.66283365e+09 1.66283367e+09 1.66283369e+09
#  1.66283371e+09 1.66283372e+09 1.66283374e+09 1.66283376e+09
#  1.66283377e+09 1.66283379e+09 1.66283381e+09 1.66283382e+09
#  1.66283384e+09 1.66283386e+09 1.66283388e+09 1.66283389e+09
#  1.66283391e+09 1.66283393e+09 1.66283394e+09 1.66283396e+09
#  1.66283398e+09 1.66283400e+09 1.66283401e+09 1.66283403e+09
#  1.66283405e+09 1.66283406e+09 1.66283408e+09 1.66283410e+09
#  1.66283411e+09 1.66283413e+09 1.66283415e+09 1.66283417e+09
#  1.66283418e+09 1.66283420e+09 1.66283422e+09 1.66283423e+09
#  1.66283425e+09 1.66283427e+09 1.66283428e+09 1.66283430e+09
#  1.66283432e+09 1.66283434e+09 1.66283435e+09 1.66283437e+09
#  1.66283439e+09 1.66283440e+09 1.66283442e+09 1.66283444e+09
#  1.66283445e+09 1.66283447e+09 1.66283449e+09 1.66283451e+09
#  1.66283452e+09 1.66283454e+09 1.66283456e+09 1.66283457e+09
#  1.66283459e+09 1.66283461e+09 1.66283462e+09 1.66283464e+09
#  1.66283466e+09 1.66283468e+09 1.66283469e+09 1.66283471e+09
#  1.66283473e+09 1.66283474e+09 1.66283476e+09 1.66283478e+09
#  1.66283479e+09 1.66283481e+09 1.66283483e+09 1.66283485e+09
#  1.66283486e+09 1.66283488e+09 1.66283490e+09 1.66283491e+09
#  1.66283493e+09 1.66283495e+09 1.66283497e+09 1.66283498e+09
#  1.66283500e+09 1.66283502e+09 1.66283503e+09 1.66283505e+09
#  1.66283507e+09 1.66283508e+09 1.66283510e+09 1.66283512e+09
#  1.66283514e+09 1.66283515e+09 1.66283517e+09 1.66283519e+09
#  1.66283520e+09 1.66283522e+09 1.66283524e+09 1.66283525e+09
#  1.66283527e+09 1.66283529e+09 1.66283531e+09 1.66283532e+09
#  1.66283534e+09 1.66283536e+09 1.66283537e+09 1.66283539e+09
#  1.66283541e+09 1.66283543e+09 1.66283544e+09 1.66283546e+09
#  1.66283548e+09 1.66283549e+09 1.66283551e+09 1.66283553e+09
#  1.66283554e+09 1.66283556e+09 1.66283558e+09 1.66283560e+09
#  1.66283561e+09 1.66283563e+09 1.66283565e+09 1.66283566e+09
#  1.66283568e+09 1.66283570e+09 1.66283571e+09 1.66283573e+09
#  1.66283575e+09 1.66283577e+09 1.66283578e+09 1.66283580e+09
#  1.66283582e+09 1.66283583e+09 1.66283585e+09 1.66283587e+09
#  1.66283588e+09 1.66283590e+09 1.66283592e+09 1.66283594e+09
#  1.66283595e+09 1.66283597e+09 1.66283599e+09 1.66283600e+09
#  1.66283602e+09 1.66283604e+09 1.66283606e+09 1.66283607e+09
#  1.66283609e+09 1.66283611e+09 1.66283612e+09 1.66283614e+09
#  1.66283616e+09 1.66283617e+09 1.66283619e+09 1.66283621e+09
#  1.66283623e+09 1.66283624e+09 1.66283626e+09 1.66283628e+09
#  1.66283629e+09 1.66283631e+09 1.66283633e+09 1.66283634e+09
#  1.66283636e+09 1.66283638e+09 1.66283640e+09 1.66283641e+09
#  1.66283643e+09 1.66283645e+09 1.66283646e+09 1.66283648e+09
#  1.66283650e+09 1.66283651e+09 1.66283653e+09 1.66283655e+09
#  1.66283657e+09 1.66283658e+09 1.66283660e+09 1.66283662e+09
#  1.66283663e+09 1.66283665e+09 1.66283667e+09 1.66283669e+09
#  1.66283670e+09 1.66283672e+09 1.66283674e+09 1.66283675e+09
#  1.66283677e+09 1.66283679e+09 1.66283680e+09 1.66283682e+09
#  1.66283684e+09 1.66283686e+09 1.66283687e+09 1.66283689e+09
#  1.66283691e+09 1.66283692e+09 1.66283694e+09 1.66283696e+09
#  1.66283697e+09 1.66283699e+09 1.66283701e+09 1.66283703e+09
#  1.66283704e+09 1.66283706e+09 1.66283708e+09 1.66283709e+09
#  1.66283711e+09 1.66283713e+09 1.66283715e+09 1.66283716e+09
#  1.66283718e+09 1.66283720e+09 1.66283721e+09 1.66283723e+09
#  1.66283725e+09 1.66283726e+09 1.66283728e+09 1.66283730e+09
#  1.66283732e+09 1.66283733e+09 1.66283735e+09 1.66283737e+09
#  1.66283738e+09 1.66283740e+09 1.66283742e+09 1.66283743e+09
#  1.66283745e+09 1.66283747e+09 1.66283749e+09 1.66283750e+09
#  1.66283752e+09 1.66283754e+09 1.66283755e+09 1.66283757e+09
#  1.66283759e+09 1.66283760e+09 1.66283762e+09 1.66283764e+09
#  1.66283766e+09 1.66283767e+09 1.66283769e+09 1.66283771e+09
#  1.66283772e+09 1.66283774e+09 1.66283776e+09 1.66283778e+09
#  1.66283779e+09 1.66283781e+09 1.66283783e+09 1.66283784e+09
#  1.66283786e+09 1.66283788e+09 1.66283789e+09 1.66283791e+09
#  1.66283793e+09 1.66283795e+09 1.66283796e+09 1.66283798e+09
#  1.66283800e+09 1.66283801e+09 1.66283803e+09 1.66283805e+09
#  1.66283806e+09 1.66283808e+09 1.66283810e+09 1.66283812e+09]
# <ipython-input-50-7ba029fe33ce>:23: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(freqs,ts,np.array(mags_all))

# %%
plt.plot(freqs,np.mean(np.array(mags_all),axis=0))

# %%
two_tone_power_sweep(probe_power_list=np.arange(-10,10,2),read_freq=read_freq,probe_freq_center=5.72e9, span =100e6,read_power=-40,sweep_pts=1000,avgs=10,ifbw=300)
# Out:
# 00003_twotoneVsPowerTransmission.h5
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 5.670 GHz
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# C:\Program Files\slab-master\slab\datamanagement.py:247: H5pyDeprecationWarning: The default file mode will change to 'r' (read-only) in h5py 3.0. To suppress this warning, pass the mode you need to h5py.File(), or set the global default h5.get_config().default_file_mode, or set the environment variable H5PY_DEFAULT_READONLY=1. Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. See the docs for details.
#   h5py.File.__init__(self, *args, **kwargs)
# finished downloading at frequency 5.670 GHz
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 5.670 GHz
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 5.670 GHz
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 5.670 GHz
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 5.670 GHz
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 5.670 GHz
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 5.670 GHz
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 5.670 GHz
# Setting up pulsed parameters
# set read freq
# Read Now On
# Qubit Drive Now ON
# finished downloading at frequency 5.670 GHz

# %%
np.arange(-20,-5,2)
# Out:
# array([-20, -18, -16, -14, -12, -10,  -8,  -6])

# %%
filename = "D:\\OneDriveGershenson-lab\\Rutgers University\\GERSHENSON LAB - Documents\\OurData\\measMW\\T182\\data\\00003_twotoneVsPowerTransmission.h5"

with h5py.File(filename, 'r') as f:
    mags = f['mags']
    freqs = f['freq']
    phases = f['phases']
    probe_power=f['probe_power']
    probe_power=np.array(probe_power[:]).flatten()
    mags=np.array(mags[:])
    phases=np.array(phases[:]).flatten()
    freqs=np.array(freqs[0,:]).flatten()
    for key in f.keys():
        print(key)
# Out:
# freq
# mags
# phases
# probe_power
# read_power

# %%
plt.pcolormesh(freqs,probe_power,mags)
# Out:
# <ipython-input-56-d3570496d40a>:1: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(freqs,probe_power,mags)

# %%
avec=probe_power
fvec=freqs
mag=10**(mags/20)
Qfaclst=[]
linewidth=[]
reslst=[]
f,ax=plt.subplots()
for i in range(len(avec)):
    p = fitlor(fvec,-mag[i],showfit=False)
    ax.plot(fvec,-lorfunc(p,fvec),'r-',alpha=1)
    ax.plot(fvec,mag[i])

    nu_res = p[2]
    Qfac = nu_res/p[3]/2
    Qfaclst=np.append(Qfaclst,Qfac)
    linewidth=np.append(linewidth,p[3])
    reslst=np.append(reslst,nu_res)
    

#plt.xlim(149.6e6,150e6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-91555ea6b6ca> in <module>
#       8 for i in range(len(avec)):
#       9     p = fitlor(fvec,-mag[i],showfit=False)
# ---> 10     ax.plot(fvec,-lorfunc(p,fvec),'r-',alpha=1)
#      11     ax.plot(fvec,mag[i])
#      12
#
# NameError: name 'lorfunc' is not defined

# %%
f,ax=plt.subplots()

ax.plot(avec[1:],reslst[1:],'x')
print('dispersion= ',np.max(reslst)-np.min(reslst[1:]))
# Out:
# dispersion=  1765071.877234459

# %%
f,ax=plt.subplots()

#ax.plot(avec,Qfaclst,'x')
ax.plot(avec[1:],2*linewidth[1:]/1e6,'x')

# ax.set_xscale('log')
# ax.set_yscale('log')

ax.set_xlabel('amplitude of 2nd tone (14dBm)',size=16)
ax.set_ylabel('line width (MHz)',size=16)
# Out:
# Text(0, 0.5, 'line width (MHz)')

# %%
from slab.dsfit import*

# %%
filename = "D:\\OneDriveGershenson-lab\\Rutgers University\\GERSHENSON LAB - Documents\\OurData\\measMW\\PNAX\\data\\00064_twotone_CW_.h5"

with h5py.File(filename, 'r') as f:
    mags = f['mags']
    freqs = f['freq']
    phases = f['phases']
    mags=np.array(mags[:]).flatten()
    phases=np.array(phases[:]).flatten()
    freqs=np.array(freqs[:]).flatten()
    for key in f.keys():
        print(key)
# Out:
# freq
# mags
# phases
# probe_power
# read_power

# %%
fig = plt.figure(figsize = (10,5))
ax = fig.add_subplot(111)

ax.plot(freqs,mags,'-')

# %%
fig = plt.figure(figsize = (10,5))
ax = fig.add_subplot(111)

ax.plot(freqs,mags,'-')

# %%
fig = plt.figure(figsize = (10,5))
ax = fig.add_subplot(111)

ax.plot(freqs,mags,'-')

# %%
from slab.dsfit import *

# %%
f,ax=plt.subplots()
p = fitlor(freqs,10**(-mags/np.max(mags)),showfit=True)
# ax.plot(freqs,-lorfunc(p,freqs),'r-')
# ax.plot(freqs,-20**(-mags/np.max(mags)))

nu_res = p[2]
Qfac = nu_res/p[3]/2
print(Qfac)
# Out:
# 1002.4022732916783

# %%
plt.plot(20**(-mags/np.max(mags)),np.abs(phases))

# %%
nu_res
# Out:
# 7706357404.1135435

# %%
Qfac
# Out:
# 1471.7786550470769

# %%
np.max(mags)
# Out:
# -37.64102768979738
